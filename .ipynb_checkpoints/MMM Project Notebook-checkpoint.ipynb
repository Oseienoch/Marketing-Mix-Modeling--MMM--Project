# %% [markdown]
# ## Project Outline
#
#  1. Project Setup
#  2. Data Preprocessing
#  3. Exploratory Data Analysis (EDA)
#  4. Econometric Modeling

# %% [markdown]
# ### 1. Project Setup

# %%
#Install Necessary Libraries

import pandas as pd
import numpy as np
import qgrid
qgrid.set_grid_option('forceFitColumns', False)

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Handle Missing Values
import missingno as msno

# %% [markdown]
# ### 2. Data Preprocessing

# %% [markdown]
# #### 2.1 Load Data

# %%
data = pd.read_excel('/Users/enochosei/Personal Projects/Marketing Mix Modeling (MMM) Project/Marketing-Mix-Modeling--MMM--Project/MMM_data.xlsx', sheet_name='Sheet1')

# %% [markdown]
# #### 2.2 Inspect Data

# %%
# qgrid.show_grid(data)
data.sample(6)
# Out:
#                 TV Manufacturing Brand       DATE  DEMAND   \
# 841   TV Manufacturing & Supplier Unit 2012-04-21     7245
# 316   TV Manufacturing & Supplier Unit 2010-11-13    14009
# 720   TV Manufacturing & Supplier Unit 2011-12-22     8716
# 2492  TV Manufacturing & Supplier Unit 2016-10-28     5082
# 1087  TV Manufacturing & Supplier Unit 2012-12-23     3610
# 863   TV Manufacturing & Supplier Unit 2012-05-13     5005
#
#       Consumer Price Index (CPI)  Consumer Confidence Index(CCI)  \
# 841                        101.3                           105.3
# 316                        104.2                            98.7
# 720                        101.4                            97.0
# 2492                       102.1                           102.7
# 1087                       103.4                           102.9
# 863                        101.3                           105.3
#
#       Producer Price Index (PPI)  Unit Price ($)  POS/ Supply Data  SALES ($)  \
# 841                        100.4          361.60              4266  1542585.6
# 316                        103.5          361.62             15280  5525553.6
# 720                        100.4          361.02              7240  2613784.8
# 2492                       103.3          361.62              6240  2256508.8
# 1087                        99.5          361.60              4216  1524505.6
# 863                         99.5          361.60              5453  1971804.8
#
#       Advertising Expenses (SMS)  Advertising Expenses(Newspaper ads)  \
# 841                      66.1017                            13.261653
# 316                      44.4388                            10.814541
# 720                      64.2846                            13.314926
# 2492                     58.1144                            13.070430
# 1087                     41.5698                            10.810839
# 863                      38.7023                            10.894057
#
#       Advertising Expenses(Radio)  Advertising Expenses(TV)  \
# 841                       90.5800                 1389.4068
# 316                       81.4573                 1140.6888
# 720                       83.8178                 1382.5472
# 2492                      80.0450                 1371.6737
# 1087                      78.3685                 1107.2965
# 863                       79.2653                 1151.4504
#
#       Advertising Expenses(Internet)  GRP (NewPaper ads)  GRP(SMS)  GRP(Radio  \
# 841                         4190.619            559.3350   98.8613    97.1364
# 316                         4414.286            996.8130   33.7128    92.0455
# 720                         4364.333           1758.4020    0.0000   133.5000
# 2492                        4524.381            587.1600    0.0000    99.0000
# 1087                        2360.512             78.5261   15.0240   123.8180
# 863                         3563.992            715.7929   60.3637   115.3161
#
#       GRP(Internet)    GRP(TV)
# 841        231.2273   931.4545
# 316        246.8182   962.8182
# 720        244.9091  1398.6364
# 2492       220.6818  1072.0455
# 1087       311.9083  1014.8182
# 863        249.0141   945.1364

# %%
data.describe()
# Out:
#             DEMAND   Consumer Price Index (CPI)  \
# count   2613.000000                 2613.000000
# mean    5021.434367                  102.609989
# std     2681.197808                    1.381355
# min     1610.000000                  101.300000
# 25%     2436.000000                  101.400000
# 50%     4636.000000                  102.300000
# 75%     6834.000000                  103.400000
# max    18565.000000                  106.500000
#
#        Consumer Confidence Index(CCI)  Producer Price Index (PPI)  \
# count                     2613.000000                 2613.000000
# mean                       103.152315                  102.238232
# std                          3.167221                    2.037774
# min                         96.300000                   99.500000
# 25%                        102.700000                  100.400000
# 50%                        103.600000                  102.700000
# 75%                        104.600000                  103.500000
# max                        107.900000                  107.200000
#
#        Unit Price ($)  POS/ Supply Data     SALES ($)  \
# count     2613.000000       2613.000000  2.613000e+03
# mean       363.275128       4522.970915  1.641507e+06
# std         26.372958       2603.996535  9.416673e+05
# min        282.140000       1510.000000  4.627096e+05
# 25%        361.600000       1776.000000  6.717679e+05
# 50%        361.620000       4412.000000  1.605095e+06
# 75%        361.620000       6266.000000  2.267206e+06
# max        400.100000      16482.000000  5.960221e+06
#
#        Advertising Expenses (SMS)  Advertising Expenses(Newspaper ads)  \
# count                 2613.000000                          2613.000000
# mean                    60.388495                            12.651179
# std                     13.557190                             1.117926
# min                     37.916700                            10.027128
# 25%                     47.554100                            11.885714
# 50%                     61.267900                            13.186582
# 75%                     71.012200                            13.437482
# max                     89.728300                            14.104193
#
#        Advertising Expenses(Radio)  Advertising Expenses(TV)  \
# count                  2613.000000               2613.000000
# mean                     88.074643               1324.501468
# std                      12.569956                123.677327
# min                      62.968800               1067.155700
# 25%                      78.098100               1251.250000
# 50%                      84.129200               1380.696200
# 75%                      98.639000               1416.171400
# max                     118.467700               1479.456500
#
#        Advertising Expenses(Internet)  GRP (NewPaper ads)     GRP(SMS)  \
# count                     2613.000000         2613.000000  2613.000000
# mean                      3079.184067          505.296876    30.618203
# std                       1520.891014          488.147782    31.570754
# min                          0.000000            5.659000     0.000000
# 25%                       2226.429000          114.957000     0.000000
# 50%                       3302.667000          221.528000    26.119600
# 75%                       4237.095000          854.310000    46.782000
# max                       6354.571000         1791.183000   144.995100
#
#          GRP(Radio  GRP(Internet)      GRP(TV)
# count  2613.000000    2613.000000  2613.000000
# mean    139.437260     286.228665  1146.114128
# std     146.042432     138.406620   822.991163
# min      66.863600     191.181800   697.636400
# 25%      95.136400     234.954500   849.545500
# 50%     109.636400     261.454500   928.545500
# 75%     126.045500     291.318200  1114.863600
# max    1169.409100    1540.429400  7307.318200

# %% [markdown]
# #### 2.3 Handle Missing Values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2613 entries, 0 to 2612
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   TV Manufacturing Brand               2613 non-null   object
#  1   DATE                                 2613 non-null   datetime64[ns]
#  2   DEMAND                               2613 non-null   int64
#  3   Consumer Price Index (CPI)           2613 non-null   float64
#  4   Consumer Confidence Index(CCI)       2613 non-null   float64
#  5   Producer Price Index (PPI)           2613 non-null   float64
#  6   Unit Price ($)                       2613 non-null   float64
#  7   POS/ Supply Data                     2613 non-null   int64
#  8   SALES ($)                            2613 non-null   float64
#  9   Advertising Expenses (SMS)           2613 non-null   float64
#  10  Advertising Expenses(Newspaper ads)  2613 non-null   float64
#  11  Advertising Expenses(Radio)          2613 non-null   float64
#  12  Advertising Expenses(TV)             2613 non-null   float64
#  13  Advertising Expenses(Internet)       2613 non-null   float64
#  14  GRP (NewPaper ads)                   2613 non-null   float64
#  15  GRP(SMS)                             2613 non-null   float64
#  16  GRP(Radio                            2613 non-null   float64
#  17  GRP(Internet)                        2613 non-null   float64
#  18  GRP(TV)                              2613 non-null   float64
# dtypes: datetime64[ns](1), float64(15), int64(2), object(1)
# memory usage: 388.0+ KB

# %%
data.isnull().sum()
# Out:
# TV Manufacturing Brand                 0
# DATE                                   0
# DEMAND                                 0
# Consumer Price Index (CPI)             0
# Consumer Confidence Index(CCI)         0
# Producer Price Index (PPI)             0
# Unit Price ($)                         0
# POS/ Supply Data                       0
# SALES ($)                              0
# Advertising Expenses (SMS)             0
# Advertising Expenses(Newspaper ads)    0
# Advertising Expenses(Radio)            0
# Advertising Expenses(TV)               0
# Advertising Expenses(Internet)         0
# GRP (NewPaper ads)                     0
# GRP(SMS)                               0
# GRP(Radio                              0
# GRP(Internet)                          0
# GRP(TV)                                0
# dtype: int64

# %% [markdown]
# **There appear to be no missing/null values and the data types are correctly specified.**

# %% [markdown]
# #### 2.3 Outlier Detection

# %%
data.plot(subplots=True, layout=(4,5), kind='box', figsize=(12,14), patch_artist=True)
plt.subplots_adjust(wspace=0.5);

# %% [markdown]
# #### 2.4 Initial Feature Engineering

# %%
data['Year'] = data['DATE'].dt.year
data['Month'] = data['DATE'].dt.month
data['DayOfWeek'] = data['DATE'].dt.dayofweek
data['Total Expenditure']

# %%
data.sample(1)
# Out:
#                TV Manufacturing Brand       DATE  DEMAND   \
# 379  TV Manufacturing & Supplier Unit 2011-01-15     9739
#
#      Consumer Price Index (CPI)  Consumer Confidence Index(CCI)  \
# 379                       104.5                            99.9
#
#      Producer Price Index (PPI)  Unit Price ($)  POS/ Supply Data   SALES ($)  \
# 379                       102.7          361.02              7542  2722812.84
#
#      Advertising Expenses (SMS)  ...  Advertising Expenses(TV)  \
# 379                     68.4878  ...                  1433.561
#
#      Advertising Expenses(Internet)  GRP (NewPaper ads)  GRP(SMS)  GRP(Radio  \
# 379                        5082.667             467.509   93.5075   114.2273
#
#      GRP(Internet)    GRP(TV)  Year  Month  DayOfWeek
# 379       324.5909  1271.5455  2011      1          5
#
# [1 rows x 22 columns]

# %% [markdown]
# ### 3. Exploratory Data Analysis (EDA)
